# %%
# !pip install -r to_do.txt

# %%
#!pip install protobuf-to-dict

# %%
import sys
print(sys.version)
# Out:
# 3.8.13 (default, Mar 28 2022, 06:59:08) [MSC v.1916 64 bit (AMD64)]

# %%
import numpy as np
import pandas as pd

# %%
#!python atac_script.py

# %%
#pip install protobuf3-to-dict

# %%
df = pd.read_csv(r"./tu_1693992630.csv", sep = ";")

# %%
df = pd.read_csv(r"./tu_1693992630.csv", sep = ";")

# %%
# !python atac_script_loop.py
# Out:
# 0
# Hello
# 0 12.117243766784668
# 1
# 1 10.020272970199585
# 2
# 2 10.926259756088257
# 3
# 3 21.09154510498047
# 4
# Trying again
# IncompleteRead(751530 bytes read, 8245 more expected)
# 4 13.916886329650879
# 5
# Trying again
# DecodeError('Error parsing message')
# 5 26.79063057899475
# 6
# 6 10.803873538970947
# 7
# 7 20.972089290618896
# 8
# Trying again
# IncompleteRead(743420 bytes read, 12307 more expected)
# 8 8.46732473373413
# 9
# 9 10.54085922241211
# 10
# 10 21.888716459274292
# 11
# 11 10.9142324924469
# 12
# Trying again
# DecodeError('Error parsing message')
# 12 9.007304191589355
# 13
# 13 11.164927005767822
# 14
# 14 10.936427593231201
# 15
# 15 19.41177749633789

# %%
# !python atac_script_loop.py
# Out:
# ^C

# %%
df1 = pd.read_csv(r".\feeddata\tu_1693996531.csv", sep = ";")

# %%
df2 = pd.read_csv(r".\feeddata\tu_1693996620.csv", sep = ";")

# %%
df1.head()
# Out:
#    id  isDeleted tripUpdate.trip.tripId tripUpdate.trip.startTime  \
# 0   1      False               0#723-17                  12:30:00
# 1   2      False               0#725-14                  12:18:00
# 2   3      False              0#4512-12                  12:18:00
# 3   4      False               0#4687-8                  12:20:00
# 4   5      False              0#4514-11                  12:16:00
#
#    tripUpdate.trip.startDate tripUpdate.trip.routeId  \
# 0                   20230906                     087
# 1                   20230906                     089
# 2                   20230906                     870
# 3                   20230906                     228
# 4                   20230906                     870
#
#    tripUpdate.trip.directionId  \
# 0                          0.0
# 1                          0.0
# 2                          1.0
# 3                          0.0
# 4                          0.0
#
# ...

# %%
df2.head()
# Out:
#    id  isDeleted tripUpdate.trip.tripId tripUpdate.trip.startTime  \
# 0   1      False               0#723-17                  12:30:00
# 1   2      False               0#725-14                  12:18:00
# 2   3      False              0#4512-12                  12:18:00
# 3   4      False               0#4687-8                  12:20:00
# 4   5      False              0#2927-10                  12:54:00
#
#    tripUpdate.trip.startDate tripUpdate.trip.routeId  \
# 0                   20230906                     087
# 1                   20230906                     089
# 2                   20230906                     870
# 3                   20230906                     228
# 4                   20230906                     713
#
#    tripUpdate.trip.directionId  \
# 0                          0.0
# 1                          0.0
# 2                          1.0
# 3                          0.0
# 4                          0.0
#
# ...

# %%
dftotal = pd.concat([df1,df2])

# %%
dftotal
# Out:
#       id  isDeleted tripUpdate.trip.tripId tripUpdate.trip.startTime  \
# 0      1      False               0#723-17                  12:30:00
# 1      2      False               0#725-14                  12:18:00
# 2      3      False              0#4512-12                  12:18:00
# 3      4      False               0#4687-8                  12:20:00
# 4      5      False              0#4514-11                  12:16:00
# ..   ...        ...                    ...                       ...
# 885  886      False               0#5137-8                  12:39:00
# 886  887      False              0#1923-10                  12:06:00
# 887  888      False               0#4636-9                  11:31:00
# 888  889      False               0#2068-9                  12:40:00
# 889  890      False               0#4643-8                  12:16:00
#
#      tripUpdate.trip.startDate tripUpdate.trip.routeId  \
# 0                     20230906                     087
# ...

# %%
len(df1)
# Out:
# 877

# %%
len(df2)
# Out:
# 890

# %%
len(dftotal)
# Out:
# 1767

# %%
890+877
# Out:
# 1767

# %%
dftotal.head()
# Out:
#    id  isDeleted tripUpdate.trip.tripId tripUpdate.trip.startTime  \
# 0   1      False               0#723-17                  12:30:00
# 1   2      False               0#725-14                  12:18:00
# 2   3      False              0#4512-12                  12:18:00
# 3   4      False               0#4687-8                  12:20:00
# 4   5      False              0#4514-11                  12:16:00
#
#    tripUpdate.trip.startDate tripUpdate.trip.routeId  \
# 0                   20230906                     087
# 1                   20230906                     089
# 2                   20230906                     870
# 3                   20230906                     228
# 4                   20230906                     870
#
#    tripUpdate.trip.directionId  \
# 0                          0.0
# 1                          0.0
# 2                          1.0
# 3                          0.0
# 4                          0.0
#
# ...
