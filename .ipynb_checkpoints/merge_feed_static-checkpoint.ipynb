# %%
import pandas as pd
import os
import numpy
pd.set_option()

# %%
tu_feed  = pd.read_csv('./output_data/tu_feed.csv')
tu_feed = tu_feed.rename(columns={'tripUpdate.trip.tripId': 'trip_id'})
vp_feed  = pd.read_csv('./output_data/vp_feed.csv')
vp_feed = vp_feed.rename(columns={'vehicle.trip.tripId': 'trip_id'})

# %%
tu_feed.shape
# Out:
# (205711, 13)

# %%
vp_feed.shape
# Out:
# (205675, 19)

# %%
atac_state = pd.read_csv(r"./output_data/atac_state_full.csv")
# Out:
# /var/folders/wp/hp437k1x56n9y9m31x7fsx640000gn/T/ipykernel_6496/3109705268.py:1: DtypeWarning: Columns (3,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   atac_state = pd.read_csv(r"./output_data/atac_state_full.csv")

# %%
atac_state.shape
# Out:
# (4039455, 11)

# %%
atac_state.merge(tu_feed, on = "trip_id",how = "inner").sort_values(["trip_id",
# Out:
#            trip_id arrival_time departure_time stop_id  stop_sequence  \
# 0        0#2196-12     12:24:00       12:24:00   74761             14
# 1        0#2196-12     12:24:00       12:24:00   74761             14
# 2        0#2196-12     12:24:00       12:24:00   74761             14
# 3        0#2196-12     12:24:00       12:24:00   74761             14
# 4        0#2196-12     12:24:00       12:24:00   74761             14
# ...            ...          ...            ...     ...            ...
# 6551480   0#3254-2     15:18:38       15:18:38   78862              2
# 6551481   0#3254-2     15:20:18       15:20:18   78863              3
# 6551482   0#3254-2     15:20:18       15:20:18   78863              3
# 6551483   0#3254-2     15:23:00       15:23:00   74654              4
# 6551484   0#3254-2     15:23:00       15:23:00   74654              4
#
#          stop_headsign  shape_dist_traveled  timepoint route_id service_id  \
# ...

# %%
df_tu_total = df_tu_total.rename(columns={'tripUpdate.trip.tripId': 'trip_id'})
df_tu_total
# Out:
#          id isDeleted    trip_id tripUpdate.trip.startTime  \
# 0         1     False   0#723-21                  14:30:00
# 1         2     False   0#725-17                  14:03:00
# 2         3     False  0#4512-14                  14:05:00
# 3         4     False   0#4687-9                  13:39:00
# 4         5     False   0#4689-9                  14:06:00
# ...     ...       ...        ...                       ...
# 205706  857     False  0#1923-12                  14:00:00
# 205707  858     False  0#4636-12                  14:34:00
# 205708  859     False  0#2068-10                  13:47:00
# 205709  860     False    0#47-11                  13:42:00
# 205710  861     False  0#4643-10                  14:17:00
#
#        tripUpdate.trip.startDate tripUpdate.trip.routeId  \
# 0                       20230906                     087
# 1                       20230906                     089
# 2                       20230906                     870
# ...

# %%
atac_state.merge(df_tu_total, on = "trip_id",how = "inner")
# Out:
# Empty DataFrame
# Columns: [trip_id, arrival_time, departure_time, stop_id, stop_sequence, stop_headsign, shape_dist_traveled, timepoint, route_id, service_id, trip_headsign, id, isDeleted, tripUpdate.trip.startTime, tripUpdate.trip.startDate, tripUpdate.trip.routeId, tripUpdate.trip.directionId, tripUpdate.stopTimeUpdate, tripUpdate.vehicle.id, tripUpdate.vehicle.label, tripUpdate.timestamp, tripUpdate.delay, max_time]
# Index: []
#
# [0 rows x 23 columns]
