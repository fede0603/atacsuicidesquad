# %%
import pandas as pd
import os
import numpy

# %%
# Define the folder path where your CSV files are located
folder_path = './feeddata/'

# Get a list of all files in the folder
files = os.listdir(folder_path)

# Filter files that start with 'tu' and end with '.csv'
tu_csv_files = [file for file in files if file.startswith('tu') and file.endswith('.csv')]

# Initialize an empty DataFrame to store the concatenated data
df_tu_total = pd.DataFrame()

dtypes = {'id': str,
 'isDeleted': str,
 'tripUpdate.trip.tripId': str,
 'tripUpdate.trip.startTime': str,
 'tripUpdate.trip.startDate': str,
 'tripUpdate.trip.routeId': str,
 'tripUpdate.trip.directionId': str,
 'tripUpdate.stopTimeUpdate': str,
 'tripUpdate.vehicle.id': str,
 'tripUpdate.vehicle.label': str,
 'tripUpdate.timestamp': int,
 'tripUpdate.delay': float,
 'max_time': int}

# Loop through each CSV file and concatenate them
for file in tu_csv_files:
    file_path = os.path.join(folder_path, file,  )
    data = pd.read_csv(file_path, sep = ";", dtype = dtypes)  # Read the CSV file
    df_tu_total = pd.concat([df_tu_total, data], ignore_index=True)  # Concatenate the data
# Convert Unix timestamp to datetime
df_tu_total['tripUpdate.timestamp'] = pd.to_datetime(df_tu_total['tripUpdate.timestamp'], unit='s')
df_tu_total['max_time'] = pd.to_datetime(df_tu_total['max_time'], unit='s')

df_tu_total.to_csv('./output_data/tu_feed.csv', index=False)

# %%
# Get a list of all files in the folder
files = os.listdir(folder_path)

# Filter files that start with 'tu' and end with '.csv'
tu_csv_files = [file for file in files if file.startswith('vp') and file.endswith('.csv')]

# Initialize an empty DataFrame to store the concatenated data
df_vp_total = pd.DataFrame()

{'id': str,
 'isDeleted': str,
 'vehicle.trip.tripId': str,
 'vehicle.trip.startTime': str,
 'vehicle.trip.startDate': str,
 'vehicle.trip.routeId': str,
 'vehicle.trip.directionId': str,
 'vehicle.position.latitude': str,
 'vehicle.position.longitude': str,
 'vehicle.position.odometer': str,
 'vehicle.currentStopSequence': str,
 'vehicle.currentStatus': str,
 'vehicle.timestamp': int,
 'vehicle.stopId': str,
 'vehicle.vehicle.id': str,
 'vehicle.vehicle.label': str,
 'vehicle.occupancyStatus': str,
 'vehicle.trip.scheduleRelationship': str,
 'max_time': int}

# Loop through each CSV file and concatenate them
for file in tu_csv_files:
    file_path = os.path.join(folder_path, file,  )
    data = pd.read_csv(file_path, sep = ";", dtype = dtypes)  # Read the CSV file
    df_vp_total = pd.concat([df_vp_total, data], ignore_index=True)  # Concatenate the data


df_vp_total['vehicle.timestamp'] = pd.to_datetime(df_vp_total['vehicle.timestamp'], unit='s')
df_vp_total['max_time'] = pd.to_datetime(df_vp_total['max_time'], unit='s')

# Save the concatenated data to a new CSV file
df_vp_total.to_csv('./output_data/vp_feed.csv', index=False)

# %%
df_vp_total.shape
# Out:
# (205675, 19)

# %%
df_tu_total.shape
# Out:
# (205711, 13)

# %%
df_vp_total
# Out:
#          id isDeleted vehicle.trip.tripId vehicle.trip.startTime  \
# 0         1     False            0#725-19               15:13:00
# 1         2     False           0#4512-15               14:52:00
# 2         3     False           0#4687-10               14:58:00
# 3         4     False           0#2927-13               15:09:00
# 4         5     False           0#4513-15               15:16:00
# ...     ...       ...                 ...                    ...
# 205670  872     False           0#1923-13               14:52:00
# 205671  873     False           0#4636-12               14:34:00
# 205672  874     False           0#2068-11               14:48:00
# 205673  875     False             0#47-11               13:42:00
# 205674  876     False           0#4643-10               14:17:00
#
#         vehicle.trip.startDate vehicle.trip.routeId  vehicle.trip.directionId  \
# 0                     20230906                  089                       1.0
# 1                     20230906                  870                       0.0
# 2                     20230906                  228                       0.0
# 3                     20230906                  713                       0.0
# 4                     20230906                  870                       0.0
# ...                        ...                  ...                       ...
# 205670                20230906                   44                       0.0
# 205671                20230906                   62                       0.0
# 205672                20230906                  490                       1.0
# 205673                20230906                    H                       0.0
# 205674                20230906                   62                       0.0
#
#         vehicle.position.latitude  vehicle.position.longitude  \
# 0                       41.839270                   12.354187
# 1                       41.875412                   12.446725
# 2                       41.836143                   12.436691
# 3                       41.841660                   12.437482
# 4                       41.901520                   12.463830
# ...                           ...                         ...
# 205670                  41.884975                   12.463563
# 205671                  41.900738                   12.462905
# 205672                  41.909973                   12.487826
# 205673                  41.898632                   12.490030
# 205674                  41.899628                   12.453310
#
#         vehicle.position.odometer  vehicle.currentStopSequence  \
# 0                         24697.0                           11
# 1                         33385.0                           16
# 2                         45207.0                           25
# 3                         21608.0                           11
# 4                          1596.0                            2
# ...                           ...                          ...
# 205670                     2051.0                           26
# 205671                     2784.0                           27
# 205672                     2420.0                           23
# 205673                     3085.0                           29
# 205674                     3173.0                           29
#
#        vehicle.currentStatus   vehicle.timestamp  vehicle.stopId  \
# 0              IN_TRANSIT_TO 2023-09-06 13:19:24           71529
# 1              IN_TRANSIT_TO 2023-09-06 13:19:06           73006
# 2              IN_TRANSIT_TO 2023-09-06 13:19:26           74686
# 3              IN_TRANSIT_TO 2023-09-06 13:19:08           74639
# 4              IN_TRANSIT_TO 2023-09-06 13:19:18           82181
# ...                      ...                 ...             ...
# 205670         IN_TRANSIT_TO 2023-09-06 13:20:20           70312
# 205671         IN_TRANSIT_TO 2023-09-06 13:19:52           82181
# 205672         IN_TRANSIT_TO 2023-09-06 13:20:30           71405
# 205673         IN_TRANSIT_TO 2023-09-06 13:20:22           70082
# 205674         IN_TRANSIT_TO 2023-09-06 13:19:36           72084
#
#         vehicle.vehicle.id  vehicle.vehicle.label vehicle.occupancyStatus  \
# 0                      197                    246                     NaN
# 1                      199                    248                     NaN
# 2                      202                    251                     NaN
# 3                      206                    255                     NaN
# 4                      209                    258                     NaN
# ...                    ...                    ...                     ...
# 205670                4624                    839    MANY_SEATS_AVAILABLE
# 205671                4625                    840    MANY_SEATS_AVAILABLE
# 205672                4626                    841    MANY_SEATS_AVAILABLE
# 205673                4627                    842                     NaN
# 205674                4628                    843                     NaN
#
#         vehicle.trip.scheduleRelationship            max_time
# 0                                     NaN 2023-09-06 13:19:31
# 1                                     NaN 2023-09-06 13:19:31
# 2                                     NaN 2023-09-06 13:19:31
# 3                                     NaN 2023-09-06 13:19:31
# 4                                     NaN 2023-09-06 13:19:31
# ...                                   ...                 ...
# 205670                                NaN 2023-09-06 13:20:32
# 205671                                NaN 2023-09-06 13:20:32
# 205672                                NaN 2023-09-06 13:20:32
# 205673                                NaN 2023-09-06 13:20:32
# 205674                                NaN 2023-09-06 13:20:32
#
# [205675 rows x 19 columns]

# %%
atac_state = pd.read_csv(r"./output_data/atac_state_full.csv")
# Out:
# /var/folders/wp/hp437k1x56n9y9m31x7fsx640000gn/T/ipykernel_6468/3109705268.py:1: DtypeWarning: Columns (3,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   atac_state = pd.read_csv(r"./output_data/atac_state_full.csv")

# %%
atac_state
# Out:
#            trip_id arrival_time departure_time stop_id  stop_sequence  \
# 0            1#1-2     07:30:00       07:30:00   74761              1
# 1            1#1-2     07:34:26       07:34:26   74763              2
# 2            1#1-2     07:36:26       07:36:26   74765              3
# 3            1#1-2     07:41:16       07:41:16   74716              4
# 4            1#1-2     07:47:00       07:47:00   82543              5
# ...            ...          ...            ...     ...            ...
# 4039450  0#4001-23     23:57:20       23:57:20   76058              3
# 4039451  0#4001-23     23:58:14       23:58:14   76059              4
# 4039452  0#4001-23     23:58:48       23:58:48   76060              5
# 4039453  0#4001-23     23:59:12       23:59:12   76061              6
# 4039454  0#4001-23     23:59:48       23:59:48   76062              7
#
#          stop_headsign  shape_dist_traveled  timepoint route_id service_id  \
# 0                  NaN                    0          1      T01       1#28
# 1                  NaN                 1167          0      T01       1#28
# 2                  NaN                 1697          0      T01       1#28
# 3                  NaN                 2963          0      T01       1#28
# 4                  NaN                 4466          1      T01       1#28
# ...                ...                  ...        ...      ...        ...
# 4039450            NaN                  491          0      980        0#7
# 4039451            NaN                  823          0      980        0#7
# 4039452            NaN                 1031          0      980        0#7
# 4039453            NaN                 1172          0      980        0#7
# 4039454            NaN                 1392          0      980        0#7
#
#                         trip_headsign
# 0                  TUSCOLANA/ANAGNINA
# 1                  TUSCOLANA/ANAGNINA
# 2                  TUSCOLANA/ANAGNINA
# 3                  TUSCOLANA/ANAGNINA
# 4                  TUSCOLANA/ANAGNINA
# ...                               ...
# 4039450  OSPEDALE S. FILIPPO NERI (H)
# 4039451  OSPEDALE S. FILIPPO NERI (H)
# 4039452  OSPEDALE S. FILIPPO NERI (H)
# 4039453  OSPEDALE S. FILIPPO NERI (H)
# 4039454  OSPEDALE S. FILIPPO NERI (H)
#
# [4039455 rows x 11 columns]

# %%
df_vp_total = df_vp_total.rename(columns={'vehicle.trip.tripId': 'trip_id'})
df_vp_total
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_vp_total = df_vp_total.rename(columns={'vehicle.trip.tripId': 'trip_id'})
#       2 df_vp_total
#
# NameError: name 'df_vp_total' is not defined

# %%
atac_state.merge(df_vp_total, on = "trip_id",how = "inner")
# Out:
# Empty DataFrame
# Columns: [trip_id, arrival_time, departure_time, stop_id, stop_sequence, stop_headsign, shape_dist_traveled, timepoint, route_id, service_id, trip_headsign, id, isDeleted, vehicle.trip.startTime, vehicle.trip.startDate, vehicle.trip.routeId, vehicle.trip.directionId, vehicle.position.latitude, vehicle.position.longitude, vehicle.position.odometer, vehicle.currentStopSequence, vehicle.currentStatus, vehicle.timestamp, vehicle.stopId, vehicle.vehicle.id, vehicle.vehicle.label, vehicle.occupancyStatus, vehicle.trip.scheduleRelationship, max_time]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_tu_total = df_tu_total.rename(columns={'tripUpdate.trip.tripId': 'trip_id'})
df_tu_total
# Out:
#          id isDeleted    trip_id tripUpdate.trip.startTime  \
# 0         1     False   0#723-21                  14:30:00
# 1         2     False   0#725-17                  14:03:00
# 2         3     False  0#4512-14                  14:05:00
# 3         4     False   0#4687-9                  13:39:00
# 4         5     False   0#4689-9                  14:06:00
# ...     ...       ...        ...                       ...
# 205706  857     False  0#1923-12                  14:00:00
# 205707  858     False  0#4636-12                  14:34:00
# 205708  859     False  0#2068-10                  13:47:00
# 205709  860     False    0#47-11                  13:42:00
# 205710  861     False  0#4643-10                  14:17:00
#
#        tripUpdate.trip.startDate tripUpdate.trip.routeId  \
# 0                       20230906                     087
# 1                       20230906                     089
# 2                       20230906                     870
# 3                       20230906                     228
# 4                       20230906                     228
# ...                          ...                     ...
# 205706                  20230906                      44
# 205707                  20230906                      62
# 205708                  20230906                     490
# 205709                  20230906                       H
# 205710                  20230906                      62
#
#        tripUpdate.trip.directionId  \
# 0                              0.0
# 1                              1.0
# 2                              1.0
# 3                              0.0
# 4                              0.0
# ...                            ...
# 205706                         1.0
# 205707                         0.0
# 205708                         0.0
# 205709                         0.0
# 205710                         0.0
#
#                                 tripUpdate.stopTimeUpdate  \
# 0       [{'stopSequence': 1, 'departure': {'delay': -3...
# 1       [{'stopSequence': 20, 'arrival': {'delay': -52...
# 2       [{'stopSequence': 18, 'arrival': {'delay': 20,...
# 3       [{'stopSequence': 43, 'arrival': {'delay': -71...
# 4       [{'stopSequence': 21, 'arrival': {'delay': -37...
# ...                                                   ...
# 205706  [{'stopSequence': 32, 'arrival': {'delay': -19...
# 205707  [{'stopSequence': 1, 'departure': {'delay': 10...
# 205708  [{'stopSequence': 34, 'arrival': {'delay': -27...
# 205709  [{'stopSequence': 1, 'departure': {'delay': 29...
# 205710  [{'stopSequence': 6, 'arrival': {'delay': 662,...
#
#        tripUpdate.vehicle.id tripUpdate.vehicle.label tripUpdate.timestamp  \
# 0                        194                     0243  2023-09-06 12:24:14
# 1                        197                     0246  2023-09-06 12:24:07
# 2                        199                     0248  2023-09-06 12:24:22
# 3                        202                     0251  2023-09-06 12:24:11
# 4                        203                     0252  2023-09-06 12:24:10
# ...                      ...                      ...                  ...
# 205706                  4624                     0839  2023-09-06 12:34:49
# 205707                  4625                     0840  2023-09-06 12:35:05
# 205708                  4626                     0841  2023-09-06 12:35:24
# 205709                  4627                     0842  2023-09-06 12:34:53
# 205710                  4628                     0843  2023-09-06 12:35:30
#
#         tripUpdate.delay            max_time
# 0                 -358.0 2023-09-06 12:24:32
# 1                 -508.0 2023-09-06 12:24:32
# 2                  -48.0 2023-09-06 12:24:32
# 3                 -720.0 2023-09-06 12:24:32
# 4                 -406.0 2023-09-06 12:24:32
# ...                  ...                 ...
# 205706            -192.0 2023-09-06 12:35:31
# 205707              40.0 2023-09-06 12:35:31
# 205708            -272.0 2023-09-06 12:35:31
# 205709            2900.0 2023-09-06 12:35:31
# 205710             648.0 2023-09-06 12:35:31
#
# [205711 rows x 13 columns]

# %%
atac_state.merge(df_tu_total, on = "trip_id",how = "inner")
# Out:
# Empty DataFrame
# Columns: [trip_id, arrival_time, departure_time, stop_id, stop_sequence, stop_headsign, shape_dist_traveled, timepoint, route_id, service_id, trip_headsign, id, isDeleted, tripUpdate.trip.startTime, tripUpdate.trip.startDate, tripUpdate.trip.routeId, tripUpdate.trip.directionId, tripUpdate.stopTimeUpdate, tripUpdate.vehicle.id, tripUpdate.vehicle.label, tripUpdate.timestamp, tripUpdate.delay, max_time]
# Index: []
#
# [0 rows x 23 columns]
